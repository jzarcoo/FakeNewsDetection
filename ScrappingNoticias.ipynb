# %% [markdown]
# # Web Scrapping

# %%
import pandas as pd
import requests as rq
from bs4 import BeautifulSoup

# %%
URL = "https://www.bbc.com/news"

# %%
try:
    res = rq.get(URL)
    res.raise_for_status()
    print("La solicitud fue exitosa")
except Exception as e:
    print(f"Error al obtener la página: {res.status_code}")
# Out:
# La solicitud fue exitosa

# %%
soup = BeautifulSoup(res.text, 'html.parser')

# %%
links = soup.find_all('a', href=True)
articulos = [link['href'] for link in links if '/news/articles/' in link['href']]
print(f"{len(articulos)} Artículos")
print(articulos[:3])
# Out:
# 34 Artículos
# ['/news/articles/cp9yv1gnzyvo', '/news/articles/cevx7lkznm1o', '/news/articles/cvge4l109r3o']

# %%
def get_titulo(soup_articulo):
    return soup_articulo.find('h1').get_text(strip=True) if titulo else ""

def get_texto(soup_articulo):
    text_blocks = soup_articulo.find_all('div', {'data-component': 'text-block'})
    return ' '.join(
        p.get_text(strip=True) for block in text_blocks for p in block.find_all('p')
    )

def get_etiquetas(soup_articulo):
    tag_block = soup_articulo.find('div', {'data-component': 'tags'})
    nuevos_articulos = [a.get_text(strip=True) for a in tag_block.find_all('a')] if tag_block else []
    return ", ".join(nuevos_articulos)

def get_contribuyentes(soup_articulo):
    contributors_block = soup_articulo.find('div', {'data-testid': 'byline-new-contributors'})
    contribuyentes = [span.get_text(strip=True) for span in contributors_block.find_all('span', {'class': 'sc-b42e7a8f-7 kItaYD'})] if contributors_block else []
    return ", ".join(contribuyentes)

# def get_enlaces_topics(soup_articulo):
#     tag_block = soup_articulo.find('div', {'data-component': 'tags'})
#     return [a['href'] for a in tag_block.find_all('a', href=True)] if tag_block else []

# def get_enlaces(topics):
#     articulos = []
#     for t in topics:
#         links = soup.find_all('a', href=True)
#         articulos = [link['href'] for link in links if '/news/articles/' in link['href']]
#     return articulos

# %%
data = []
for articulo in articulos:
    link = f"https://www.bbc.com{articulo}"
    articulo_res = rq.get(link)
    soup_articulo = BeautifulSoup(articulo_res.text, 'html.parser')
    titulo = get_titulo(soup_articulo)
    texto = get_texto(soup_articulo)
    tags = get_etiquetas(soup_articulo)
    contribuyentes = get_contribuyentes(soup_articulo)
    if titulo and texto:
        data.append({
            'Titulo': titulo,
            'Texto': texto,
            'Etiquetas': tags,
            'Contribuyentes': contribuyentes,
            'URL': link,
        })
    # nuevos_articulos = get_enlaces(get_enlaces_topics(soup_articulo))

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                                                Titulo  \
# 0   US deports hundreds of Venezuelans despite cou...
# 1   Tornadoes and dust storms leave at least 34 de...
# 2          Trump moves to close down Voice of America
# 3   Fisherman rescued after 95 days adrift eating ...
# 4   Tornadoes and dust storms leave at least 34 de...
# 5   Death toll from North Macedonia nightclub fire...
# 6   How our noisy world is seriously damaging our ...
# 7   South Africa should not be 'bullied' by US in ...
# 8   Pope Francis says he faces 'period of trial' i...
# 9   US launches wave of air strikes on Yemen's Hou...
# 10  They had a fairytale American childhood - but ...
# 11  The untold story of the battle that helped end...
# 12  'I was duped into leaving London for school in...
# 13  Netflix's $320m sci-fi blockbuster is 'soulles...
# 14   14 things the Trump administration did this week
# 15  The untold story of the battle that helped end...
# 16  Creativity or cultural invasion? A fashion sho...
# 17  Design versus reality: Are some new football s...
# 18  'I was duped into leaving London for school in...
# 19  Hackman's children not named in actor's $80m will
# 20  Serbia's largest-ever rally sees 325,000 prote...
# 21  US rejects 'impractical' Hamas demands as Gaza...
# 22  Hackman's children not named in actor's $80m will
# 23  Serbia's largest-ever rally sees 325,000 prote...
# 24  US deports hundreds of Venezuelans despite cou...
# 25         Trump moves to close down Voice of America
# 26  Death toll from North Macedonia nightclub fire...
# 27  Fisherman rescued after 95 days adrift eating ...
# 28  Hackman's children not named in actor's $80m will
# 29  How our noisy world is seriously damaging our ...
# 30  South Africa should not be 'bullied' by US in ...
# 31  O'Neill's Washington boycott opportunistic - I...
# 32  Tornadoes and dust storms leave at least 34 de...
# 33  Trump blocked from using wartime law for depor...
#
#                                                 Texto  \
# 0   Planes carrying more than 200 Venezuelans depo...
# 1   At least 34 people have died in the US after v...
# 2   US President Donald Trump has signed an order ...
# 3   A Peruvian fisherman who survived 95 days lost...
# 4   At least 34 people have died in the US after v...
# 5   At least 59 people have been killed and more t...
# 6   We are surrounded by an invisible killer. One ...
# 7   Opposition parties in South Africa have called...
# 8   Pope Francis has said he faces a "period of tr...
# 9   The US has launched a "decisive and powerful" ...
# 10  After Kim Visintine put her son to bed every n...
# 11  Operation Varsity "was the battle that ended" ...
# 12  When my mother told me at the age of 16 that w...
# 13  Netflix's latest big-budget film The Electric ...
# 14  The eighth week of Donald Trump's second term ...
# 15  Operation Varsity "was the battle that ended" ...
# 16  A fashion show held last week in a picturesque...
# 17  In the world of billionaires and the similarly...
# 18  When my mother told me at the age of 16 that w...
# 19  The will of legendary actor Gene Hackman has b...
# 20  Hundreds of thousands of people descended on S...
# 21  Talks to extend the Gaza ceasefire have failed...
# 22  The will of legendary actor Gene Hackman has b...
# 23  Hundreds of thousands of people descended on S...
# 24  Planes carrying more than 200 Venezuelans depo...
# 25  US President Donald Trump has signed an order ...
# 26  At least 59 people have been killed and more t...
# 27  A Peruvian fisherman who survived 95 days lost...
# 28  The will of legendary actor Gene Hackman has b...
# 29  We are surrounded by an invisible killer. One ...
# 30  Opposition parties in South Africa have called...
# 31  Taoiseach Micheál Martin has said First Minist...
# 32  At least 34 people have died in the US after v...
# 33  A federal judge has stopped US President Donal...
#
#                                             Etiquetas  \
# 0               El Salvador, Venezuela, United States
# 1   Missouri, Tornadoes, Texas, United States, Okl...
# 2                         Donald Trump, United States
# 3                        Peru, Pacific Ocean, Ecuador
# 4   Missouri, Tornadoes, Texas, United States, Okl...
# 5                                     North Macedonia
# 6           Medical research, Health, Noise pollution
# 7                                South Africa, Africa
# 8   Catholicism, Vatican City, Pope Francis, Roman...
# 9                  Middle East, Houthis, Donald Trump
# 10                    Missouri, United States, Cancer
# 11  Bollington, Royal Air Force, History, Rivenhal...
# 12                                      Ghana, Africa
# 13       Streaming, Millie Bobby Brown, Film, Netflix
# 14             Elon Musk, Donald Trump, United States
# 15  Bollington, Royal Air Force, History, Rivenhal...
# 16  Asia, Kashmir tensions, India, Fashion, Articl...
# 17                                       Architecture
# 18                                      Ghana, Africa
# 19           Culture, Film, New Mexico, United States
# 20                                   Serbia, Belgrade
# 21        Middle East, Israel-Gaza war, Israel, Hamas
# 22           Culture, Film, New Mexico, United States
# 23                                   Serbia, Belgrade
# 24              El Salvador, Venezuela, United States
# 25                        Donald Trump, United States
# 26                                    North Macedonia
# 27                       Peru, Pacific Ocean, Ecuador
# 28           Culture, Film, New Mexico, United States
# 29          Medical research, Health, Noise pollution
# 30                               South Africa, Africa
# 31  Washington DC, Sinn Féin, Republic of Ireland,...
# 32  Missouri, Tornadoes, Texas, United States, Okl...
# 33              Immigration, Venezuela, United States
#
#                                        Contribuyentes  \
# 0                                      Brandon Drenon
# 1   Thomas Mackintosh, Lisa Lambert & Tiffany Wert...
# 2                   Thomas Mackintosh & Merlyn Thomas
# 3                                        Rachel Hagan
# 4   Thomas Mackintosh, Lisa Lambert & Tiffany Wert...
# 5                          Rachel Hagan, Guy Delauney
# 6                                     James Gallagher
# 7                                 Danai Nesta Kupemba
# 8                         Adam Goldsmith & Seher Asaf
# 9                                        Malu Cursino
# 10                                    Sophie Williams
# 11                                      Katy Prickett
# 12                                   Mark Wilberforce
# 13                                         Ian Youngs
# 14                                   Johanna Chisholm
# 15                                      Katy Prickett
# 16                                   Cherylann Mollan
# 17                                    George Sandeman
# 18                                   Mark Wilberforce
# 19                                 Samantha Granville
# 20                                      Guy De Launey
# 21                      Rushdi Abu Alouf, Maia Davies
# 22                                 Samantha Granville
# 23                                      Guy De Launey
# 24                                     Brandon Drenon
# 25                  Thomas Mackintosh & Merlyn Thomas
# 26                         Rachel Hagan, Guy Delauney
# 27                                       Rachel Hagan
# 28                                 Samantha Granville
# 29                                    James Gallagher
# 30                                Danai Nesta Kupemba
# 31
# 32  Thomas Mackintosh, Lisa Lambert & Tiffany Wert...
# 33                                       Lisa Lambert
#
#                                                URL
# 0   https://www.bbc.com/news/articles/cp9yv1gnzyvo
# 1   https://www.bbc.com/news/articles/cevx7lkznm1o
# 2   https://www.bbc.com/news/articles/cvge4l109r3o
# 3   https://www.bbc.com/news/articles/cj92438d3xmo
# 4   https://www.bbc.com/news/articles/cevx7lkznm1o
# 5   https://www.bbc.com/news/articles/c70wdedp20wo
# 6   https://www.bbc.com/news/articles/crmjdm2m4yjo
# 7   https://www.bbc.com/news/articles/cge10nnynzlo
# 8   https://www.bbc.com/news/articles/crrd17xp79zo
# 9   https://www.bbc.com/news/articles/c05mvr3j3yro
# 10  https://www.bbc.com/news/articles/c2e7011n03vo
# 11  https://www.bbc.com/news/articles/c0q1wn9zy3xo
# 12  https://www.bbc.com/news/articles/c2kg1ezyv5xo
# 13  https://www.bbc.com/news/articles/cdelxr18pzlo
# 14  https://www.bbc.com/news/articles/clyjx2erlxlo
# 15  https://www.bbc.com/news/articles/c0q1wn9zy3xo
# 16  https://www.bbc.com/news/articles/clynd24rnngo
# 17  https://www.bbc.com/news/articles/cewkzk5qv0lo
# 18  https://www.bbc.com/news/articles/c2kg1ezyv5xo
# 19  https://www.bbc.com/news/articles/c7985ld2lrro
# 20  https://www.bbc.com/news/articles/cx2g8v32q30o
# 21  https://www.bbc.com/news/articles/cr7230vrkmko
# 22  https://www.bbc.com/news/articles/c7985ld2lrro
# 23  https://www.bbc.com/news/articles/cx2g8v32q30o
# 24  https://www.bbc.com/news/articles/cp9yv1gnzyvo
# 25  https://www.bbc.com/news/articles/cvge4l109r3o
# 26  https://www.bbc.com/news/articles/c70wdedp20wo
# 27  https://www.bbc.com/news/articles/cj92438d3xmo
# 28  https://www.bbc.com/news/articles/c7985ld2lrro
# 29  https://www.bbc.com/news/articles/crmjdm2m4yjo
# 30  https://www.bbc.com/news/articles/cge10nnynzlo
# 31  https://www.bbc.com/news/articles/cly68rng2jno
# 32  https://www.bbc.com/news/articles/cevx7lkznm1o
# 33  https://www.bbc.com/news/articles/c89yk405lg9o

# %%
n = 0
print(df['URL'][n])
print(df['Titulo'][n])
print(df['Contribuyentes'][n])
print(df['Etiquetas'][n])
print(df['Texto'][n])
# Out:
# https://www.bbc.com/news/articles/cp9yv1gnzyvo
# US deports hundreds of Venezuelans despite court order
# Brandon Drenon
# El Salvador, Venezuela, United States
# Planes carrying more than 200 Venezuelans deported by the US have landed in El Salvador, hours after a US judge ordered the Trump administration not to do so. El Salvador's president, Nayib Bukele, wrote on social media that 238 members of the Venezuelan gang Tren de Aragua had arrived, along with 23 members of the international MS-13 gang, on Sunday morning. Their arrival in the central American nation came aftera federal judge blocked US President Donald Trump from invoking a centuries-old wartime lawto justify the deportations - something Bukele made fun of in a later post. "Oopsie... Too late," he said. The move by the US to send alleged criminals from other countries to El Salvador was an arrangement US Secretary of State Marco Rubio previously called "the most unprecedented and extraordinary migratory agreement anywhere in the world". Bukele wrote that the detainees were immediately transferred to El Salvador's Terrorism Confinement Center (Cecot) "for a period of one year", something that was "renewable" - suggesting they could be held there for longer. "The United States will pay a very low fee for them, but a high one for us," he added. Rubio confirmed the alleged gang members arrival in El Salvador and thanked Bukele, calling him "the strongest security leader in our region". Hours before, on Saturday evening, US District Judge James Boasberg ordered a halt to deportations covered by Trump's proclamation, which invoked the Alien Enemies Act of 1798. The law allows the government to detain and deport people threatening the country's safety without due process. Venezuela criticised invoking the wartime measure, saying it "unjustly criminalises Venezuelan migration" and "evokes the darkest episodes in the history of humanity, from slavery to the horror of the Nazi concentration camps". After hearing that planes with deportees had taken off, Judge Boasberg ordered them to turn back, the Washington Post reported. Rubio said in a statement on Sunday that the deportations happened under the Alien Enemies Act, and made no mention of the judge's ruling. He said: "Hundreds of violent criminals were sent out of our country." Their deportation despite the judge's ruling has raised legal questions. A lawyer from a rights group involved in the lawsuit against the White House said she had asked the government on Sunday whether the court's order had been violated. "[We] are waiting to hear, as well as trying to do our own investigation," Lee Gelernt with the American Civil Liberties Union (ACLU) said in a statement. The Department of Justice had appealed against the judge's ruling overnight, according to the BBC's media partner CBS News. The BBC has contacted the Justice Department for comment. A video attached to one of Bukele's social media post shows lines of people with their hands and feet shackled being escorted by armed officials from the planes. Some are placed into the back of armoured vehicles, while others, hunched over as officers push their heads down, are forced onto buses. The video also shows an aerial view of a long, winding police escort leading the buses into El Salvador's notorious mega-jail Cecot. The newly built maximum-security jail is part of Bukele's effort to crack down on the country's organised crime. The facility, which can hold up to 40,000 people, has been criticised by human rights groups for maltreatment of inmates. The arrangement between the US and El Salvador is a sign of strengthening diplomatic ties. "Thank you for your assistance and friendship," Rubio told Bukele on Sunday. El Salvador was the second country Rubio, the US's top diplomat, visited after he was sworn in. During that trip,which took place in February, Bukele made an initial offer to take US deportees, saying it would help pay for the massive Cecot facility. The latest deportations under Trump's second term are part of the president's long-running crusade against illegal immigration in the US. In January, Trump signed an executive  ...

# %%
path = "./dataset/"
df.to_csv(path + "BBC_Noticias.csv", index=False)
