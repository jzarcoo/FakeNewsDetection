# %% [markdown]
# # Web Scrapping

# %%
import pandas as pd
import requests as rq
from bs4 import BeautifulSoup

# %%
URL = "https://www.bbc.com/news"

# %%
try:
    res = rq.get(URL)
    res.raise_for_status()
    print("La solicitud fue exitosa")
except Exception as e:
    print(f"Error al obtener la página: {res.status_code}")
# Out:
# La solicitud fue exitosa

# %%
soup = BeautifulSoup(res.text, 'html.parser')

# %%
links = soup.find_all('a', href=True)
articulos = [link['href'] for link in links if '/news/articles/' in link['href']]

# %%
data = []
for articulo in articulos:
    link = f"https://www.bbc.com{articulo}"
    articulo_res = rq.get(link)
    soup_articulo = BeautifulSoup(articulo_res.text, 'html.parser')
    titulo = soup_articulo.find('h1')
    texto =  ' '.join([palabra for p in soup_articulo.find_all('p') for palabra in p.text.strip().lower().split() if palabra.isalpha()])
    if titulo and texto:
        data.append({
            'Titulo': titulo.get_text(),
            'Texto': texto
        })

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                                                Titulo  \
# 0     Putin sets out conditions for Ukraine ceasefire
# 1   Is Putin ready for a ceasefire or playing for ...
# 2   USAID kept Kajol alive – but after the cuts sh...
# 3   Top Democrat Schumer backs Republican spending...
# 4   Is Putin ready for a ceasefire or playing for ...
# 5      Trump threatens 200% tariff on alcohol from EU
# 6   'Killed in front of our eyes': How the Pakista...
# 7   UN experts accuse Israel of sexual violence an...
# 8   Donatella steps down as Versace creative director
# 9   Judge orders Trump administration to give fire...
# 10  Duda: US nuclear weapons in Poland would be 'd...
# 11  Measles cases pick up as RFK promotes unproven...
# 12  Peace talks are in parallel universe, say Ukra...
# 13  'They killed all these young people' - BBC inv...
# 14  Duterte's first night in ICC custody is a pivo...
# 15  The blunt-speaking Canadian taking his fight w...
# 16  'He strangled me without asking' - experts say...
# 17  'They killed all these young people' - BBC inv...
# 18  Holi 2025: India comes alive with the festival...
# 19  Weekly quiz: Who joined Kylie on the King's pe...
# 20  Duterte's first night in ICC custody is a pivo...
# 21  US influencer draws backlash for stealing baby...
# 22  Abercombie & Fitch must pay for ex-CEO's crimi...
# 23  'Huawei lobbyists' held in Belgium raids over ...
# 24  Naples residents camp outdoors after overnight...
# 25  Southern African forces to leave DR Congo as r...
# 26  Abercombie & Fitch must pay for ex-CEO's crimi...
# 27  German spy agency 'believed Covid likely start...
# 28  'Huawei lobbyists' held in Belgium raids over ...
# 29    Putin sets out conditions for Ukraine ceasefire
# 30  The blunt-speaking Canadian taking his fight w...
# 31  Trump pledges to match EU and Canada's retalia...
# 32  Judge orders Trump administration to give fire...
# 33  Greenland's opposition wins election dominated...
# 34  UN experts accuse Israel of sexual violence an...
# 35  'Killed in front of our eyes': How the Pakista...
# 36  Duda: US nuclear weapons in Poland would be 'd...
# 37  Is Putin ready for a ceasefire or playing for ...
# 38  White House withdraws CDC nominee hours before...
#
#                                                 Texto
# 0   russian president vladimir putin said he agree...
# 1   russia is ready for a halt in says vladimir bu...
# 2   when kajol contracted tuberculosis in usaid ke...
# 3   the us may avert a looming government shutdown...
# 4   russia is ready for a halt in says vladimir bu...
# 5   us president donald trump has threatened a tar...
# 6   mehboob hussain was riding the train home on t...
# 7   un experts have accused israel of increasingly...
# 8   donatella versace is to step down from her cre...
# 9   a judge has ordered several federal government...
# 10  the president of andrzej has repeated his call...
# 11  cases of the incredibly contagious measles vir...
# 12  while moscow considers a temporary its militar...
# 13  freddy final moments were witnessed by a who s...
# 14  outside the international criminal detention w...
# 15  as leaders around the world try to figure out ...
# 16  this story contains descriptions of sexual ass...
# 17  freddy final moments were witnessed by a who s...
# 18  millions of indians are celebrating the festiv...
# 19  this week saw talks to end the war in ukraine ...
# 20  outside the international criminal detention w...
# 21  prime minister anthony albanese is the latest ...
# 22  abercrombie fitch must pay for the legal fees ...
# 23  belgian police have raided several locations i...
# 24  many people in and around the italian city of ...
# 25  southern african leaders have announced they w...
# 26  abercrombie fitch must pay for the legal fees ...
# 27  foreign intelligence service believed there wa...
# 28  belgian police have raided several locations i...
# 29  russian president vladimir putin said he agree...
# 30  as leaders around the world try to figure out ...
# 31  us president donald trump has pledged to impos...
# 32  a judge has ordered several federal government...
# 33  opposition has won a surprise general election...
# 34  un experts have accused israel of increasingly...
# 35  mehboob hussain was riding the train home on t...
# 36  the president of andrzej has repeated his call...
# 37  russia is ready for a halt in says vladimir bu...
# 38  the white house has withdrawn its candidate to...

# %%
path = "./dataset/"
df.to_csv(path + "BBC_Noticias.csv", index=False)
